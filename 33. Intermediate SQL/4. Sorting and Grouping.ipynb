# %% [markdown]
# This final chapter teaches you how to sort and group data. These skills will take your analyses to a new level by helping you uncover critical business insights and identify trends and performance. You'll get hands-on experience to determine which films performed the best and how movie durations and budgets changed over time.

# %% [markdown]
# ## Sorting results

# %% [markdown]
# ![1.%20Sorting%20text.png](attachment:1.%20Sorting%20text.png)

# %% [markdown]
# Correct! Because ascending is the default, indicating ASC is helpful for clarity but not required!.

# %% [markdown]
# ![2.1.%20Sorting%20single%20fields.png](attachment:2.1.%20Sorting%20single%20fields.png)

# %% [markdown]
# ![2.2.%20Sorting%20single%20fields.png](attachment:2.2.%20Sorting%20single%20fields.png)

# %% [markdown]
# Superb sorting! ORDER BY is another simple yet effective way to gain intelligence about your business and data. You now know how to extract your best and worst-performing assets with only a few lines of code.

# %% [markdown]
# ![3.1.%20Sorting%20multiple%20fields.png](attachment:3.1.%20Sorting%20multiple%20fields.png)

# %% [markdown]
# ![3.2.%20Sorting%20multiple%20fields.png](attachment:3.2.%20Sorting%20multiple%20fields.png)

# %% [markdown]
# Nicely done! The second column you order on only steps in when the first column has been ordered.

# %% [markdown]
# ## Grouping data

# %% [markdown]
# ![4.1.%20GROUP%20BY%20single%20fields.png](attachment:4.1.%20GROUP%20BY%20single%20fields.png)

# %% [markdown]
# ![4.2.%20GROUP%20BY%20single%20fields.png](attachment:4.2.%20GROUP%20BY%20single%20fields.png)

# %% [markdown]
# Great job grouping! Using GROUP BY with a time or date field such as release_year can help us identify trends such as a period of time where movies were really short!

# %% [markdown]
# ![5.%20GROUP%20BY%20multiple%20fields.png](attachment:5.%20GROUP%20BY%20multiple%20fields.png)

# %% [markdown]
# Well done! You can see how building on your SQL queries helps you gain more insights and detect trends in the data, such as how film budgets may change throughout the years.

# %% [markdown]
# ![6.%20Answering%20business%20questions.png](attachment:6.%20Answering%20business%20questions.png)

# %% [markdown]
# Well done! The year 2006 had 16 distinct languages, that's more than any other year.

# %% [markdown]
# ## Filtering grouped data

# %% [markdown]
# ![7.%20Filter%20with%20HAVING.png](attachment:7.%20Filter%20with%20HAVING.png)

# %% [markdown]
# Great job! The answer is USA with 12 different certifications.

# %% [markdown]
# ![8.%20HAVING%20and%20sorting.png](attachment:8.%20HAVING%20and%20sorting.png)

# %% [markdown]
# You did it! South Korea and Hungary seem to have pricey films... or do they? Actually, these budgets are pretty standard for their local currency.

# %% [markdown]
# ![9.%20All%20together%20now.png](attachment:9.%20All%20together%20now.png)

# %% [markdown]
# Superb work! SQL queries can get rather long, but breaking them down into individual clauses makes them easier to write.
