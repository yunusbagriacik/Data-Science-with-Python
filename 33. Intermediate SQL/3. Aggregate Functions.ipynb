# %% [markdown]
# SQL allows you to zoom in and out to better understand an entire dataset, its subsets, and its individual records. You'll learn to summarize data using aggregate functions and perform basic arithmetic calculations inside queries to gain insights into what makes a successful film.

# %% [markdown]
# ## Summarizing data

# %% [markdown]
# ![1.%20Aggregate%20functions%20and%20data%20types.png](attachment:1.%20Aggregate%20functions%20and%20data%20types.png)

# %% [markdown]
# Congratulations! You've got aggregate functions under control.

# %% [markdown]
# ![2.1.%20Practice%20with%20aggregate%20functions.png](attachment:2.1.%20Practice%20with%20aggregate%20functions.png)

# %% [markdown]
# ![2.2.%20Practice%20with%20aggregate%20functions.png](attachment:2.2.%20Practice%20with%20aggregate%20functions.png)

# %% [markdown]
# ![2.3.%20Practice%20with%20aggregate%20functions.png](attachment:2.3.%20Practice%20with%20aggregate%20functions.png)

# %% [markdown]
# ![2.4.%20Practice%20with%20aggregate%20functions.png](attachment:2.4.%20Practice%20with%20aggregate%20functions.png)

# %% [markdown]
# Well done! You'll find yourself using aggregate functions over and over again to get a quick grasp of the data in a SQL database.

# %% [markdown]
# ## Summarizing subsets

# %% [markdown]
# ![3.1.%20Combining%20aggregate%20functions%20with%20WHERE.png](attachment:3.1.%20Combining%20aggregate%20functions%20with%20WHERE.png)

# %% [markdown]
# ![3.2.%20Combining%20aggregate%20functions%20with%20WHERE.png](attachment:3.2.%20Combining%20aggregate%20functions%20with%20WHERE.png)

# %% [markdown]
# ![3.3.%20Combining%20aggregate%20functions%20with%20WHERE.png](attachment:3.3.%20Combining%20aggregate%20functions%20with%20WHERE.png)

# %% [markdown]
# ![3.4.%20Combining%20aggregate%20functions%20with%20WHERE.png](attachment:3.4.%20Combining%20aggregate%20functions%20with%20WHERE.png)

# %% [markdown]
# Nice. SQL provides us with several building blocks that we can combine in all kinds of ways, hence the name: Structured Query Language.

# %% [markdown]
# ![4.%20Using%20ROUND%28%29.png](attachment:4.%20Using%20ROUND%28%29.png)

# %% [markdown]
# Well done! The average, rounded facebook_likes is 7802.9. This insight can be used as a benchmark to measure film reviews; any film with over 7802.9 likes can be considered popular.

# %% [markdown]
# ![5.%20ROUND%28%29%20with%20a%20negative%20parameter.png](attachment:5.%20ROUND%28%29%20with%20a%20negative%20parameter.png)

# %% [markdown]
# ROUND() of applause! The ROUND() function is very handy when making financial calculations to get a top-level view or specify to the penny or cent.

# %% [markdown]
# ## Aliasing and arithmetic

# %% [markdown]
# ![6.%20Using%20arithmetic.png](attachment:6.%20Using%20arithmetic.png)

# %% [markdown]
# Correct! SQL thinks we want the answer to be an integer since we are dividing two integers. 0 is the closest integer to 0.2.

# %% [markdown]
# ![7.1.%20Aliasing%20with%20functions.png](attachment:7.1.%20Aliasing%20with%20functions.png)

# %% [markdown]
# ![7.2.%20Aliasing%20with%20functions.png](attachment:7.2.%20Aliasing%20with%20functions.png)

# %% [markdown]
# ![7.3.%20Aliasing%20with%20functions.png](attachment:7.3.%20Aliasing%20with%20functions.png)

# %% [markdown]
# Amazing work mastering arithmetic, aggregate functions, and aliasing! Now you know that our films table covers films released over ten decades, or a hundred years!

# %% [markdown]
# ![8.%20Rounding%20results.png](attachment:8.%20Rounding%20results.png)

# %% [markdown]
# That's better! Now you can clearly see how long a movie is.
