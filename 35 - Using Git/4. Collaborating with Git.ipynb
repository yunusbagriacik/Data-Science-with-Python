# %% [markdown]
# This final chapter is all about collaboration! You'll gain an introduction to remote repositories and learn how to work with them to synchronize content between the cloud and your local computer. You'll also see how to create new repositories and clone existing ones, along with discovering a workflow to minimize the risk of conflicts between local and remote repositories.

# %% [markdown]
# ## Creating repos

# %% [markdown]
# ![1.1.%20Setting%20up%20a%20new%20repo.png](attachment:1.1.%20Setting%20up%20a%20new%20repo.png)

# %% [markdown]
# ![1.3.%20Setting%20up%20a%20new%20repo.png](attachment:1.3.%20Setting%20up%20a%20new%20repo.png)

# %% [markdown]
# Impressive initialization—in just three lines of code you created a new Git repository, moved into its main directory, and created a to-do list!

# %% [markdown]
# ![2.%20Converting%20an%20existing%20project.png](attachment:2.%20Converting%20an%20existing%20project.png)

# %% [markdown]
# Great work—by converting an existing project into a Git repos your files are now being tracked! Now let's learn about an essential component of working with Git—remote branches!

# %% [markdown]
# ## Working with remotes

# %% [markdown]
# ![3.%20Cloning%20a%20repo.png](attachment:3.%20Cloning%20a%20repo.png)

# %% [markdown]
# Awesome! git clone is a very useful command for copying other repos onto your local computer, whether from another local directory or remote storage such as GitHub. Now you can build on the work John has done so far!

# %% [markdown]
# ![4.1.%20Defining%20and%20identifying%20remotes.png](attachment:4.1.%20Defining%20and%20identifying%20remotes.png)

# %% [markdown]
# ![4.2.%20Defining%20and%20identifying%20remotes.png](attachment:4.2.%20Defining%20and%20identifying%20remotes.png)

# %% [markdown]
# ## Gathering from a remote

# %% [markdown]
# ![5.1.%20Fetching%20from%20a%20remote.png](attachment:5.1.%20Fetching%20from%20a%20remote.png)

# %% [markdown]
# ![5.2.%20Fetching%20from%20a%20remote.png](attachment:5.2.%20Fetching%20from%20a%20remote.png)

# %% [markdown]
# ![6.1.%20Pulling%20from%20a%20remote.png](attachment:6.1.%20Pulling%20from%20a%20remote.png)

# %% [markdown]
# ![6.2.%20Pulling%20from%20a%20remote.png](attachment:6.2.%20Pulling%20from%20a%20remote.png)

# %% [markdown]
# ![6.3.%20Pulling%20from%20a%20remote.png](attachment:6.3.%20Pulling%20from%20a%20remote.png)

# %% [markdown]
# ![6.4.%20Pulling%20from%20a%20remote.png](attachment:6.4.%20Pulling%20from%20a%20remote.png)

# %% [markdown]
# Perfect pulling! Notice you received the output 1 file changed, 1 insertion(+), highlighting that the remote was ahead of your local repo!

# %% [markdown]
# ## Pushing to a remote

# %% [markdown]
# ![7.1.%20Pushing%20to%20a%20remote%20repo.png](attachment:7.1.%20Pushing%20to%20a%20remote%20repo.png)

# %% [markdown]
# ![7.2.%20Pushing%20to%20a%20remote%20repo.png](attachment:7.2.%20Pushing%20to%20a%20remote%20repo.png)

# %% [markdown]
# ![7.3.%20Pushing%20to%20a%20remote%20repo.png](attachment:7.3.%20Pushing%20to%20a%20remote%20repo.png)

# %% [markdown]
# ![8.2.%20Handling%20push%20conflicts.png](attachment:8.2.%20Handling%20push%20conflicts.png)

# %% [markdown]
# ![8.3.%20Handling%20push%20conflicts.png](attachment:8.3.%20Handling%20push%20conflicts.png)
