# %% [markdown]
# Next, you’ll examine how Git stores data, learn essential commands to compare files and repositories at different times, and understand the process for restoring earlier versions of files in your data projects.

# %% [markdown]
# ![1.%20Interpreting%20the%20commit%20structure.png](attachment:1.%20Interpreting%20the%20commit%20structure.png)

# %% [markdown]
# ![2.%20Viewing%20a%20repository's%20history.png](attachment:2.%20Viewing%20a%20repository's%20history.png)

# %% [markdown]
# Awesome work—the git log command is very useful for tracking changes at a high level before diving deeper into more specific version control tasks!

# %% [markdown]
# ![3.1.%20Viewing%20a%20specific%20commit.png](attachment:3.1.%20Viewing%20a%20specific%20commit.png)

# %% [markdown]
# ![3.2.%20Viewing%20a%20specific%20commit.png](attachment:3.2.%20Viewing%20a%20specific%20commit.png)

# %% [markdown]
# ## Viewing changes

# %% [markdown]
# ![4.%20Comparing%20to%20the%20second%20most%20recent%20commit.png](attachment:4.%20Comparing%20to%20the%20second%20most%20recent%20commit.png)

# %% [markdown]
# Awesome work—combining git show with a commit hash or HEAD plus the required ~ is a great way to see what happened in a specific commit!

# %% [markdown]
# ![5.%20Comparing%20commits.png](attachment:5.%20Comparing%20commits.png)

# %% [markdown]
# Yes! By using git diff you get an output showing that both of these files have been changed between these two commits!

# %% [markdown]
# ![6.%20Who%20changed%20what.png](attachment:6.%20Who%20changed%20what.png)

# %% [markdown]
# ## Undoing changes before committing

# %% [markdown]
# ![7.1.%20How%20to%20unstage%20a%20file.png](attachment:7.1.%20How%20to%20unstage%20a%20file.png)

# %% [markdown]
# ![7.2.%20How%20to%20unstage%20a%20file.png](attachment:7.2.%20How%20to%20unstage%20a%20file.png)

# %% [markdown]
# ![7.3.%20How%20to%20unstage%20a%20file.png](attachment:7.3.%20How%20to%20unstage%20a%20file.png)

# %% [markdown]
# ![8.%20Undoing%20changes%20to%20unstaged%20files.png](attachment:8.%20Undoing%20changes%20to%20unstaged%20files.png)

# %% [markdown]
# ![9.2.%20Undoing%20all%20changes.png](attachment:9.2.%20Undoing%20all%20changes.png)

# %% [markdown]
# ![10.%20Restoring%20an%20old%20version%20of%20a%20repo.png](attachment:10.%20Restoring%20an%20old%20version%20of%20a%20repo.png)

# %% [markdown]
# Nicely done! Hopefully, you won't need to restore an entire repository to an earlier state, but it is worth knowing how to do this just in case things go drastically wrong!

# %% [markdown]
# ![11.%20Deleting%20untracked%20files.png](attachment:11.%20Deleting%20untracked%20files.png)

# %% [markdown]
# Perfect! Keeping your repo clean by removing unnecessary files is very important, particularly as a project gets larger and more complex!

# %% [markdown]
# ![12.1.%20Restoring%20an%20old%20version%20of%20a%20file.png](attachment:12.1.%20Restoring%20an%20old%20version%20of%20a%20file.png)

# %% [markdown]
# ![12.2.%20Restoring%20an%20old%20version%20of%20a%20file.png](attachment:12.2.%20Restoring%20an%20old%20version%20of%20a%20file.png)

# %% [markdown]
# ![12.3.%20Restoring%20an%20old%20version%20of%20a%20file.png](attachment:12.3.%20Restoring%20an%20old%20version%20of%20a%20file.png)

# %% [markdown]
# ![12.4.%20Restoring%20an%20old%20version%20of%20a%20file.png](attachment:12.4.%20Restoring%20an%20old%20version%20of%20a%20file.png)

# %% [markdown]
# Great work—by combining log, checkout, add, and commit you've been able to revert report.md and save it as the current version in Git! In the next chapter we will learn even more about Git, including the use of branches, and how to deal with conflicting versions of files!
