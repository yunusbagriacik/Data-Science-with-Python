# %% [markdown]
# In the first chapter, you’ll learn what version control is and why it is essential for data projects. Then, you’ll discover what Git is and how to use it for a version control workflow.

# %% [markdown]
# ![1.%20Using%20the%20shell.png](attachment:1.%20Using%20the%20shell.png)

# %% [markdown]
# Super shell skills! Being able to navigate directories and interact with files is extremely beneficial as you begin to work with Git.

# %% [markdown]
# ![2.%20Checking%20the%20version%20of%20Git.png](attachment:2.%20Checking%20the%20version%20of%20Git.png)

# %% [markdown]
# Great work! The --version flag allows you to check what version of Git is installed locally, which is useful if you upgrade, or need to compare versions among colleagues.

# %% [markdown]
# ## Saving files

# %% [markdown]
# ![3.%20Where%20does%20Git%20store%20information.png](attachment:3.%20Where%20does%20Git%20store%20information.png)

# %% [markdown]
# Yes—all of the information about a repo is stored under its main directory, mh_survey.

# %% [markdown]
# ![4.%20The%20Git%20workflow.png](attachment:4.%20The%20Git%20workflow.png)

# %% [markdown]
# Excellent! These commands are used extensively when performing version control in the Shell, so they are worth remembering!

# %% [markdown]
# ![5.1.%20Adding%20a%20file.png](attachment:5.1.%20Adding%20a%20file.png)

# %% [markdown]
# ![5.2.%20Adding%20a%20file.png](attachment:5.2.%20Adding%20a%20file.png)

# %% [markdown]
# ![5.3.%20Adding%20a%20file.png](attachment:5.3.%20Adding%20a%20file.png)

# %% [markdown]
# git status is a great way to see where you are in the version control workflow, allowing you to take steps to ensure everything is up-to-date. The commit output shows that two files were changed!

# %% [markdown]
# ## Comparing files

# %% [markdown]
# ![7.%20What%20has%20changed.png](attachment:7.%20What%20has%20changed.png)

# %% [markdown]
# Yes— the git diff output shows three lines changed at line 48 in the last commit, and one additional line has been added in our current unstaged file.

# %% [markdown]
# ![8.1.%20What's%20going%20to%20be%20committed.png](attachment:8.1.%20What's%20going%20to%20be%20committed.png)

# %% [markdown]
# ![8.2.%20What's%20going%20to%20be%20committed.png](attachment:8.2.%20What's%20going%20to%20be%20committed.png)

# %% [markdown]
# ![8.3.%20What's%20going%20to%20be%20committed.png](attachment:8.3.%20What's%20going%20to%20be%20committed.png)

# %% [markdown]
# ![9.%20What's%20in%20the%20staging%20area.png](attachment:9.%20What's%20in%20the%20staging%20area.png)

# %% [markdown]
# Great work, looks like a reminder to update the analysis was added! In the next chapter, we will discover some of Git's more advanced functionality including the metadata it stores, how to look at versions from specific commits, and how to undo changes!
