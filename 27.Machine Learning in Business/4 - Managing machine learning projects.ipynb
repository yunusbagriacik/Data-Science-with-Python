# %% [markdown]
# ## Machine learning mistakes

# %% [markdown]
# ![1%20-%20Identify%20machine%20learning%20mistakes.png](attachment:1%20-%20Identify%20machine%20learning%20mistakes.png)

# %% [markdown]
# Perfect! The business should first define the requirements before building the model.

# %% [markdown]
# #### Data needs pyramid

# %% [markdown]
# ![2%20-%20Data%20needs%20pyramid.png](attachment:2%20-%20Data%20needs%20pyramid.png)

# %% [markdown]
# Congratulations, you have successfully ordered the data pyramid needs in the right sequence!

# %% [markdown]
# #### Match ML mistakes by their types

# %% [markdown]
# ![3%20-%20Match%20ML%20mistakes%20by%20their%20types.png](attachment:3%20-%20Match%20ML%20mistakes%20by%20their%20types.png)

# %% [markdown]
# Great job at tagging the right use cases to the ML mistakes!

# %% [markdown]
# ## Communication management

# %% [markdown]
# ![4%20-%20Business%20communication%20focus.png](attachment:4%20-%20Business%20communication%20focus.png)

# %% [markdown]
# Exactly, the business team does not care, nor has the expertise to provide inputs into algorithmic discussion.

# %% [markdown]
# #### Market testing

# %% [markdown]
# ![5%20-%20Market%20testing.png](attachment:5%20-%20Market%20testing.png)

# %% [markdown]
# Congratulations! You have successfully sorted the market testing steps!

# %% [markdown]
# ## Machine learning in production

# %% [markdown]
# #### Production systems

# %% [markdown]
# ![6%20-%20Production%20systems.png](attachment:6%20-%20Production%20systems.png)

# %% [markdown]
# Perfect! This is not a production system - just a file. However, it's possible that there's a production system automatically producing this file.

# %% [markdown]
# #### Production systems ML use cases

# %% [markdown]
# ![7%20-%20Production%20systems%20ML%20use%20cases.png](attachment:7%20-%20Production%20systems%20ML%20use%20cases.png)

# %% [markdown]
# Perfect! You've successfully identified the ML use cases by their production system type.

# %% [markdown]
# #### ML in production launch

# %% [markdown]
# ![8%20-%20ML%20in%20production%20launch.png](attachment:8%20-%20ML%20in%20production%20launch.png)

# %% [markdown]
# Congratulations! You have correctly ordered the implementation steps of putting machine learning in production.
