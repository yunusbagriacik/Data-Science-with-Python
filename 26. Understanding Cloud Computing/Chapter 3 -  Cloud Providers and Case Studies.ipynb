# %% [markdown]
# ## Amazon Web Services (1st in the cloud market)

# %% [markdown]
# ![AWS.png](attachment:AWS.png)

# %% [markdown]
# ![AWS%20case1.png](attachment:AWS%20case1.png)

# %% [markdown]
# ## Microsoft Azure (runner up in the cloud market)

# %% [markdown]
# ![Azure%20case%201.png](attachment:Azure%20case%201.png)

# %% [markdown]
# ![Azure.png](attachment:Azure.png)

# %% [markdown]
# That's right! Azure Blob Storage is actually a file storage service. Azure SQL Database is the database solution that was presented in the video for Microsoft Azure. In general, if the service name contains "blob", it's very likely a file storage solution.

# %% [markdown]
# ## Google Cloud (3rd in the market)

# %% [markdown]
# ![Google%20Cloud%20use%20case%201.png](attachment:Google%20Cloud%20use%20case%201.png)

# %% [markdown]
# Exactly! Lush had experienced website outages on their e-commerce platform during the previous Boxing Day, and wanted to prevent this situation from happening again.

# %% [markdown]
# ![True-false%20general.png](attachment:True-false%20general.png)

# %% [markdown]
# Nice job! You have a clear idea of the offers and strengths of the main cloud infrastructure providers.

# %% [markdown]
# ## Other actors and final thoughts

# %% [markdown]
# ![sharing%20of%20the%20market.png](attachment:sharing%20of%20the%20market.png)

# %% [markdown]
# ![services%20of%20other%20cloud%20providers.png](attachment:services%20of%20other%20cloud%20providers.png)
