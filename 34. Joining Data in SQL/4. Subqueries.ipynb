# %% [markdown]
# In this closing chapter, you’ll begin by investigating semi-joins and anti-joins. Next, you'll learn how to use nested queries. Last but not least, you’ll wrap up the course with some challenges!

# %% [markdown]
# ![1.%20Multiple%20WHERE%20clauses.png](attachment:1.%20Multiple%20WHERE%20clauses.png)

# %% [markdown]
# Nicely done. You've familiarized yourself with semi join syntax, and seen that the WHERE clause can be used in both the main query and the subquery!

# %% [markdown]
# ![2.1.%20Semi%20join.png](attachment:2.1.%20Semi%20join.png)

# %% [markdown]
# ![2.2.%20Semi%20join.png](attachment:2.2.%20Semi%20join.png)

# %% [markdown]
# ![2.3.%20Semi%20join.png](attachment:2.3.%20Semi%20join.png)

# %% [markdown]
# Well done writing your first subquery in the form of a semi join. Think of all the opportunities that open up when queries become building blocks of larger queries!

# %% [markdown]
# ![3.%20Diagnosing%20problems%20using%20anti%20join.png](attachment:3.%20Diagnosing%20problems%20using%20anti%20join.png)

# %% [markdown]
# Nice! Your anti join determined which five out of 19 countries that were not included in the INNER JOIN provided. Did you notice that Tuvalu has two currencies, and therefore shows up twice in the INNER JOIN? This is why the INNER JOIN returned 15 rather than 14 results.

# %% [markdown]
# ## Subqueries inside WHERE and SELECT

# %% [markdown]
# ![4.1.%20Subquery%20inside%20WHERE.png](attachment:4.1.%20Subquery%20inside%20WHERE.png)

# %% [markdown]
# ![4.2.%20Subquery%20inside%20WHERE.png](attachment:4.2.%20Subquery%20inside%20WHERE.png)

# %% [markdown]
# Nice work! You may recognize many of these country codes as being relatively wealthy countries, which makes sense as we might expect life expectancy to be higher in wealthier nations.

# %% [markdown]
# ![5.%20WHERE%20do%20people%20live.png](attachment:5.%20WHERE%20do%20people%20live.png)

# %% [markdown]
# Alright! You've got plenty of practice on subqueries inside WHERE. Let's move on to subqueries inside the SELECT statement.

# %% [markdown]
# ![6.1.%20Subquery%20inside%20SELECT.png](attachment:6.1.%20Subquery%20inside%20SELECT.png)

# %% [markdown]
# ![6.2.%20Subquery%20inside%20SELECT.png](attachment:6.2.%20Subquery%20inside%20SELECT.png)

# %% [markdown]
# Excellent job! Notice how the subquery involves only one additional step in your SELECT statement, whereas the JOIN and GROUP BY are a two-step process.

# %% [markdown]
# ![7.%20Subquery%20inside%20FROM.png](attachment:7.%20Subquery%20inside%20FROM.png)

# %% [markdown]
# This one brought several joining concepts together! Did you notice that the top three countries in our result are located in Africa?

# %% [markdown]
# ![8.%20Subquery%20challenge.png](attachment:8.%20Subquery%20challenge.png)

# %% [markdown]
# ![8.%20Subquery%20challenge.png](attachment:8.%20Subquery%20challenge.png)

# %% [markdown]
# ![9.%20Final%20challenge.png](attachment:9.%20Final%20challenge.png)

# %% [markdown]
# You've identified that Lima has the highest percentage of people living in the city 'proper', relative to the wider metropolitan population! Nicely done getting to the top of the summit.
